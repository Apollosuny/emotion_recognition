# %%
import numpy as np
import matplotlib.pyplot as plt
import itertools
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Flatten
from tensorflow.keras.layers import Conv2D, MaxPool2D
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import BatchNormalization, Activation
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from keras import regularizers
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report

# %%
# Ignore Warnings
import warnings
warnings.filterwarnings("ignore")

# %%
train_dir = 'data/train'
test_dir = 'data/test'

# %%
# crobed image size
batch_size = 64
img_size = (48,48)
channels = 1
img_shape = (img_size[0], img_size[1], channels)

# %%
train_datagen = ImageDataGenerator(
        rescale=1./255,
        horizontal_flip=True,  
        vertical_flip=False,
        fill_mode='nearest',
        validation_split=0.2
)
train_generator = train_datagen.flow_from_directory(train_dir,
                                                batch_size=batch_size,
                                                target_size=img_size,
                                                shuffle=True,
                                                color_mode='grayscale',
                                                class_mode='categorical',
                                                subset='training'
                                              )
validation_generator = train_datagen.flow_from_directory(train_dir,
                                                batch_size=batch_size,
                                                target_size=img_size,
                                                shuffle=True,
                                                color_mode='grayscale',
                                                class_mode='categorical',
                                                subset='validation'
                                                 )

test_datagen = ImageDataGenerator(rescale=1./255,
                                   horizontal_flip=True)
test_generator = test_datagen.flow_from_directory(test_dir,
                                                batch_size=batch_size,
                                                target_size=img_size,
                                                shuffle=True,
                                                color_mode='grayscale',
                                                class_mode='categorical')
# Out:
# Found 22968 images belonging to 7 classes.
# Found 5741 images belonging to 7 classes.
# Found 7178 images belonging to 7 classes.

# %%
g_dict = train_generator.class_indices      
classes = list(g_dict.keys())       
images, labels = next(train_generator)      

plt.figure(figsize= (20, 20))

for i in range(16):
    plt.subplot(4, 4, i + 1)
    image = images[i] / 255       
    plt.imshow(image)
    index = np.argmax(labels[i])  
    class_name = classes[index]   
    plt.title(class_name, color= 'blue', fontsize= 12)
    plt.axis('off')
plt.show()

# %%
model= tf.keras.models.Sequential()
model.add(Conv2D(32, kernel_size=(3, 3), padding='same', activation='relu', input_shape=img_shape))
model.add(Conv2D(64,(3,3), padding='same', activation='relu' ))
model.add(BatchNormalization())
model.add(MaxPool2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(128,(5,5), padding='same', activation='relu'))
model.add(BatchNormalization())
model.add(MaxPool2D(pool_size=(2, 2)))
model.add(Dropout(0.25))
    
model.add(Conv2D(512,(3,3), padding='same', activation='relu', kernel_regularizer=regularizers.l2(0.01)))
model.add(BatchNormalization())
model.add(MaxPool2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(512,(3,3), padding='same', activation='relu', kernel_regularizer=regularizers.l2(0.01)))
model.add(BatchNormalization())
model.add(MaxPool2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(512,(3,3), padding='same', activation='relu', kernel_regularizer=regularizers.l2(0.01)))
model.add(BatchNormalization())
model.add(MaxPool2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Flatten()) 
model.add(Dense(256,activation = 'relu'))
model.add(BatchNormalization())
model.add(Dropout(0.25))
    
model.add(Dense(512,activation = 'relu'))
model.add(BatchNormalization())
model.add(Dropout(0.25))

model.add(Dense(7, activation='softmax'))
model.compile(
  optimizer = Adam(learning_rate=0.0001), 
  loss='categorical_crossentropy', 
  metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_12 (Conv2D)              │ (None, 48, 48, 32)     │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_13 (Conv2D)              │ (None, 48, 48, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_14          │ (None, 48, 48, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_10 (MaxPooling2D) │ (None, 24, 24, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_14 (Dropout)            │ (None, 24, 24, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_14 (Conv2D)              │ (None, 24, 24, 128)    │       204,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_15          │ (None, 24, 24, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_11 (MaxPooling2D) │ (None, 12, 12, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_15 (Dropout)            │ (None, 12, 12, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_15 (Conv2D)              │ (None, 12, 12, 512)    │       590,336 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_16          │ (None, 12, 12, 512)    │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_12 (MaxPooling2D) │ (None, 6, 6, 512)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_16 (Dropout)            │ (None, 6, 6, 512)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_16 (Conv2D)              │ (None, 6, 6, 512)      │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_17          │ (None, 6, 6, 512)      │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_13 (MaxPooling2D) │ (None, 3, 3, 512)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_17 (Dropout)            │ (None, 3, 3, 512)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_17 (Conv2D)              │ (None, 3, 3, 512)      │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_18          │ (None, 3, 3, 512)      │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_14 (MaxPooling2D) │ (None, 1, 1, 512)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_18 (Dropout)            │ (None, 1, 1, 512)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_2 (Flatten)             │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 256)            │       131,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_19          │ (None, 256)            │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_19 (Dropout)            │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 512)            │       131,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_20          │ (None, 512)            │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_20 (Dropout)            │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_8 (Dense)                 │ (None, 7)              │         3,591 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 5,810,183 (22.16 MB)
#  Trainable params: 5,805,191 (22.15 MB)
#  Non-trainable params: 4,992 (19.50 KB)

# %%
checkpointer = [EarlyStopping(monitor = 'val_accuracy', verbose = 1, 
                              restore_best_weights=True,mode="max",patience = 5),
                ModelCheckpoint('best_model.h5.keras',monitor="val_accuracy",verbose=1,
                                save_best_only=True,mode="max")]

# %%
history = model.fit(train_generator,
                    epochs=30,
                    batch_size=64,   
                    verbose=1,
                    callbacks=[checkpointer],
                    validation_data=validation_generator)
# Out:
# Epoch 1/30
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 766ms/step - accuracy: 0.1624 - loss: 14.6984
# Epoch 1: val_accuracy improved from -inf to 0.14527, saving model to best_model.h5.keras
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 327s 889ms/step - accuracy: 0.1624 - loss: 14.6973 - val_accuracy: 0.1453 - val_loss: 13.5797
# Epoch 2/30
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 605ms/step - accuracy: 0.2062 - loss: 13.1758
# Epoch 2: val_accuracy improved from 0.14527 to 0.25118, saving model to best_model.h5.keras
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 232s 645ms/step - accuracy: 0.2062 - loss: 13.1747 - val_accuracy: 0.2512 - val_loss: 11.8177
# Epoch 3/30
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 589ms/step - accuracy: 0.2218 - loss: 11.6332
# Epoch 3: val_accuracy improved from 0.25118 to 0.26912, saving model to best_model.h5.keras
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 225s 626ms/step - accuracy: 0.2218 - loss: 11.6321 - val_accuracy: 0.2691 - val_loss: 10.3030
# Epoch 4/30
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 604ms/step - accuracy: 0.2641 - loss: 10.0826
# Epoch 4: val_accuracy improved from 0.26912 to 0.32538, saving model to best_model.h5.keras
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 229s 638ms/step - accuracy: 0.2641 - loss: 10.0816 - val_accuracy: 0.3254 - val_loss: 8.9545
# Epoch 5/30
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 587ms/step - accuracy: 0.3102 - loss: 8.6142
# Epoch 5: val_accuracy improved from 0.32538 to 0.36231, saving model to best_model.h5.keras
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 226s 628ms/step - accuracy: 0.3102 - loss: 8.6133 - val_accuracy: 0.3623 - val_loss: 7.4988
# Epoch 6/30
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 596ms/step - accuracy: 0.3462 - loss: 7.3235
# Epoch 6: val_accuracy improved from 0.36231 to 0.37903, saving model to best_model.h5.keras
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 228s 634ms/step - accuracy: 0.3462 - loss: 7.3227 - val_accuracy: 0.3790 - val_loss: 6.5231
# Epoch 7/30
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 578ms/step - accuracy: 0.3805 - loss: 6.1912
# Epoch 7: val_accuracy improved from 0.37903 to 0.39784, saving model to best_model.h5.keras
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 221s 615ms/step - accuracy: 0.3805 - loss: 6.1905 - val_accuracy: 0.3978 - val_loss: 5.6626
# Epoch 8/30
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 601ms/step - accuracy: 0.4092 - loss: 5.2743
# Epoch 8: val_accuracy improved from 0.39784 to 0.42327, saving model to best_model.h5.keras
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 230s 639ms/step - accuracy: 0.4092 - loss: 5.2737 - val_accuracy: 0.4233 - val_loss: 4.6908
# Epoch 9/30
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 594ms/step - accuracy: 0.4298 - loss: 4.5104
# Epoch 9: val_accuracy improved from 0.42327 to 0.43459, saving model to best_model.h5.keras
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 226s 630ms/step - accuracy: 0.4298 - loss: 4.5099 - val_accuracy: 0.4346 - val_loss: 4.0551
# Epoch 10/30
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 592ms/step - accuracy: 0.4593 - loss: 3.8757
# Epoch 10: val_accuracy improved from 0.43459 to 0.49103, saving model to best_model.h5.keras
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 227s 630ms/step - accuracy: 0.4593 - loss: 3.8753 - val_accuracy: 0.4910 - val_loss: 3.4531
# Epoch 11/30
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 583ms/step - accuracy: 0.4816 - loss: 3.3576
# Epoch 11: val_accuracy improved from 0.49103 to 0.52047, saving model to best_model.h5.keras
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 222s 619ms/step - accuracy: 0.4816 - loss: 3.3573 - val_accuracy: 0.5205 - val_loss: 2.9805
# Epoch 12/30
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 603ms/step - accuracy: 0.5064 - loss: 2.9479
# Epoch 12: val_accuracy improved from 0.52047 to 0.52447, saving model to best_model.h5.keras
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 229s 638ms/step - accuracy: 0.5064 - loss: 2.9477 - val_accuracy: 0.5245 - val_loss: 2.6825
# Epoch 13/30
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 583ms/step - accuracy: 0.5247 - loss: 2.6299
# Epoch 13: val_accuracy improved from 0.52447 to 0.53945, saving model to best_model.h5.keras
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 223s 622ms/step - accuracy: 0.5247 - loss: 2.6298 - val_accuracy: 0.5395 - val_loss: 2.4423
# Epoch 14/30
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 578ms/step - accuracy: 0.5384 - loss: 2.3854
# Epoch 14: val_accuracy improved from 0.53945 to 0.55565, saving model to best_model.h5.keras
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 221s 614ms/step - accuracy: 0.5384 - loss: 2.3853 - val_accuracy: 0.5557 - val_loss: 2.2136
# Epoch 15/30
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 575ms/step - accuracy: 0.5584 - loss: 2.1744
# Epoch 15: val_accuracy did not improve from 0.55565
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 219s 611ms/step - accuracy: 0.5584 - loss: 2.1744 - val_accuracy: 0.5551 - val_loss: 2.0848
# Epoch 16/30
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 578ms/step - accuracy: 0.5647 - loss: 2.0443
# Epoch 16: val_accuracy did not improve from 0.55565
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 221s 616ms/step - accuracy: 0.5647 - loss: 2.0442 - val_accuracy: 0.5450 - val_loss: 2.0153
# Epoch 17/30
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 580ms/step - accuracy: 0.5711 - loss: 1.9403
# Epoch 17: val_accuracy did not improve from 0.55565
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 221s 616ms/step - accuracy: 0.5711 - loss: 1.9402 - val_accuracy: 0.5485 - val_loss: 1.9492
# Epoch 18/30
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 580ms/step - accuracy: 0.5950 - loss: 1.8348
# Epoch 18: val_accuracy improved from 0.55565 to 0.59450, saving model to best_model.h5.keras
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 221s 615ms/step - accuracy: 0.5950 - loss: 1.8348 - val_accuracy: 0.5945 - val_loss: 1.8058
# Epoch 19/30
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 535ms/step - accuracy: 0.5980 - loss: 1.7852
# Epoch 19: val_accuracy did not improve from 0.59450
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 203s 566ms/step - accuracy: 0.5980 - loss: 1.7851 - val_accuracy: 0.5809 - val_loss: 1.7975
# Epoch 20/30
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 566ms/step - accuracy: 0.6189 - loss: 1.7167
# Epoch 20: val_accuracy improved from 0.59450 to 0.59641, saving model to best_model.h5.keras
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 219s 609ms/step - accuracy: 0.6189 - loss: 1.7168 - val_accuracy: 0.5964 - val_loss: 1.7739
# Epoch 21/30
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 594ms/step - accuracy: 0.6125 - loss: 1.7138
# Epoch 21: val_accuracy did not improve from 0.59641
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 225s 627ms/step - accuracy: 0.6125 - loss: 1.7138 - val_accuracy: 0.5921 - val_loss: 1.7802
# Epoch 22/30
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 584ms/step - accuracy: 0.6248 - loss: 1.6697
# Epoch 22: val_accuracy improved from 0.59641 to 0.60216, saving model to best_model.h5.keras
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 222s 619ms/step - accuracy: 0.6247 - loss: 1.6697 - val_accuracy: 0.6022 - val_loss: 1.7319
# Epoch 23/30
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 576ms/step - accuracy: 0.6325 - loss: 1.6581
# Epoch 23: val_accuracy did not improve from 0.60216
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 223s 621ms/step - accuracy: 0.6325 - loss: 1.6581 - val_accuracy: 0.6002 - val_loss: 1.7412
# Epoch 24/30
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 594ms/step - accuracy: 0.6433 - loss: 1.6251
# Epoch 24: val_accuracy did not improve from 0.60216
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 226s 628ms/step - accuracy: 0.6433 - loss: 1.6251 - val_accuracy: 0.5731 - val_loss: 1.7986
# Epoch 25/30
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 621ms/step - accuracy: 0.6502 - loss: 1.6184
# Epoch 25: val_accuracy did not improve from 0.60216
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 237s 659ms/step - accuracy: 0.6501 - loss: 1.6184 - val_accuracy: 0.5997 - val_loss: 1.7663
# Epoch 26/30
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 619ms/step - accuracy: 0.6627 - loss: 1.6073
# Epoch 26: val_accuracy did not improve from 0.60216
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 236s 656ms/step - accuracy: 0.6627 - loss: 1.6073 - val_accuracy: 0.5954 - val_loss: 1.7709
# Epoch 27/30
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 599ms/step - accuracy: 0.6635 - loss: 1.5954
# Epoch 27: val_accuracy improved from 0.60216 to 0.60808, saving model to best_model.h5.keras
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 228s 635ms/step - accuracy: 0.6635 - loss: 1.5954 - val_accuracy: 0.6081 - val_loss: 1.7556
# Epoch 28/30
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 607ms/step - accuracy: 0.6807 - loss: 1.5737
# Epoch 28: val_accuracy improved from 0.60808 to 0.61104, saving model to best_model.h5.keras
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 232s 646ms/step - accuracy: 0.6806 - loss: 1.5738 - val_accuracy: 0.6110 - val_loss: 1.7770
# Epoch 29/30
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 634ms/step - accuracy: 0.6837 - loss: 1.5866
# Epoch 29: val_accuracy improved from 0.61104 to 0.62446, saving model to best_model.h5.keras
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 241s 671ms/step - accuracy: 0.6836 - loss: 1.5866 - val_accuracy: 0.6245 - val_loss: 1.7564
# Epoch 30/30
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 613ms/step - accuracy: 0.6863 - loss: 1.5902
# Epoch 30: val_accuracy did not improve from 0.62446
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 235s 655ms/step - accuracy: 0.6863 - loss: 1.5903 - val_accuracy: 0.6030 - val_loss: 1.8302
# Restoring model weights from the end of the best epoch: 29.

# %%
plt.plot(history.history["loss"],'r', label="Training Loss")
plt.plot(history.history["val_loss"],'b', label="Validation Loss")
plt.legend()

# %%
plt.plot(history.history["accuracy"],'r',label="Training Accuracy")
plt.plot(history.history["val_accuracy"],'b',label="Validation Accuracy")
plt.legend()

# %%
# Define needed variables
tr_acc = history.history['accuracy']
tr_loss = history.history['loss']
val_acc = history.history['val_accuracy']
val_loss = history.history['val_loss']
index_loss = np.argmin(val_loss)
val_lowest = val_loss[index_loss]
index_acc = np.argmax(val_acc)
acc_highest = val_acc[index_acc]
Epochs = [i+1 for i in range(len(tr_acc))]
loss_label = f'best epoch= {str(index_loss + 1)}'
acc_label = f'best epoch= {str(index_acc + 1)}'

# %%
# Plot training history
plt.figure(figsize= (20, 8))
plt.style.use('fivethirtyeight')
plt.subplot(1, 2, 1)
plt.plot(Epochs, tr_loss, 'r', label= 'Training loss')
plt.plot(Epochs, val_loss, 'g', label= 'Validation loss')
plt.scatter(index_loss + 1, val_lowest, s= 150, c= 'blue', label= loss_label)
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.subplot(1, 2, 2)
plt.plot(Epochs, tr_acc, 'r', label= 'Training Accuracy')
plt.plot(Epochs, val_acc, 'g', label= 'Validation Accuracy')
plt.scatter(index_acc + 1 , acc_highest, s= 150, c= 'blue', label= acc_label)
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.tight_layout
plt.show()

# %%
ts_length = test_generator.n
test_batch_size = max(sorted([ts_length // n for n in range(1, ts_length + 1) if ts_length%n == 0 and ts_length/n <= 80]))
test_steps = ts_length // test_batch_size

train_score = model.evaluate(train_generator, steps= test_steps, verbose= 1)
valid_score = model.evaluate(validation_generator, steps= test_steps, verbose= 1)
test_score = model.evaluate(test_generator, steps= test_steps, verbose= 1)

print("Train Loss: ", train_score[0])
print("Train Accuracy: ", train_score[1])
print('-' * 20)
print("Validation Loss: ", valid_score[0])
print("Validation Accuracy: ", valid_score[1])
print('-' * 20)
print("Test Loss: ", test_score[0])
print("Test Accuracy: ", test_score[1])
# Out:
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 14s 147ms/step - accuracy: 0.7518 - loss: 1.4302
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 14s 145ms/step - accuracy: 0.6441 - loss: 1.7308
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 47s 491ms/step - accuracy: 0.6296 - loss: 1.7687
# Train Loss:  1.4321213960647583
# Train Accuracy:  0.7495167255401611
# --------------------
# Validation Loss:  1.7339410781860352
# Validation Accuracy:  0.6307263374328613
# --------------------
# Test Loss:  1.746427297592163
# Test Accuracy:  0.6340206265449524

# %%
# Test
evaluation_result = model.evaluate(test_generator)
print("Loss:", evaluation_result[0])
print("Accuracy:", evaluation_result[1])
# Out:
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 18s 162ms/step - accuracy: 0.6305 - loss: 1.7415
# Loss: 1.7535911798477173
# Accuracy: 0.630537748336792

# %%
preds = model.predict(test_generator)
y_pred = np.argmax(preds, axis=1)
# Out:
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 16s 139ms/step

# %%
g_dict = test_generator.class_indices
classes = list(g_dict.keys())

# Confusion matrix
cm = confusion_matrix(test_generator.classes, y_pred)

plt.figure(figsize= (10, 10))
plt.imshow(cm, interpolation= 'nearest', cmap= plt.cm.Blues)
plt.title('Confusion Matrix')
plt.colorbar()
tick_marks = np.arange(len(classes))
plt.xticks(tick_marks, classes, rotation= 45)
plt.yticks(tick_marks, classes)
thresh = cm.max() / 2.
for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
    plt.text(j, i, cm[i, j], horizontalalignment= 'center', color= 'white' if cm[i, j] > thresh else 'black')

plt.tight_layout()
plt.ylabel('True Label')
plt.xlabel('Predicted Label')

plt.show()

# %%
# Classification report
print(classification_report(test_generator.classes, y_pred, target_names= classes))
# Out:
#               precision    recall  f1-score   support
#
#        angry       0.14      0.12      0.13       958
#      disgust       0.05      0.02      0.03       111
#         fear       0.15      0.10      0.12      1024
#        happy       0.26      0.25      0.26      1774
#      neutral       0.17      0.20      0.18      1233
#          sad       0.19      0.24      0.21      1247
#     surprise       0.10      0.10      0.10       831
#
#     accuracy                           0.18      7178
#    macro avg       0.15      0.15      0.15      7178
# weighted avg       0.18      0.18      0.18      7178

# %%
model.save('model.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
